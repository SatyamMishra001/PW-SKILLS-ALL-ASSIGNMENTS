# %%
'''Problem 1: Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance. Implement methods to deposit and withdraw money from the account.'''

class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} successfully.")
        else:
            print("Deposit amount should be greater than zero.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawn {amount} successfully.")
        else:
            print("Insufficient balance or invalid amount.")

    def display_balance(self):
        print(f"Account Number: {self.account_number}")
        print(f"Account Holder Name: {self.account_holder_name}")
        print(f"Balance: {self.balance}")


# Test the BankAccount class
account = BankAccount("123456789", "John Doe", 1000)
account.display_balance()
print()

account.deposit(500)
account.display_balance()
print()

account.withdraw(200)
account.display_balance()
print()

account.withdraw(2000)
# Out:
# Account Number: 123456789
# Account Holder Name: John Doe
# Balance: 1000
#
# Deposited 500 successfully.
# Account Number: 123456789
# Account Holder Name: John Doe
# Balance: 1500
#
# Withdrawn 200 successfully.
# Account Number: 123456789
# Account Holder Name: John Doe
# Balance: 1300
#
# Insufficient balance or invalid amount.

# %%
'''Problem 2: Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. Implement methods to calculate the yearly bonus and display employee details.'''
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self, percentage):
        return (percentage / 100) * self.salary

    def display_details(self):
        print("Employee ID:", self.employee_id)
        print("Name:", self.name)
        print("Salary:", self.salary)


# Test the Employee class
employee1 = Employee(1, "John Doe", 50000)
employee1.display_details()
yearly_bonus = employee1.calculate_yearly_bonus(10)
print("Yearly Bonus:", yearly_bonus)
# Out:
# Employee ID: 1
# Name: John Doe
# Salary: 50000
# Yearly Bonus: 5000.0

# %%
#Problem 3: Vehicle Rental Create a class representing a vehicle rental system. Implement methods to rent a vehicle, return a vehicle, and display available vehicles.
class VehicleRentalSystem:
    def __init__(self):
        self.available_vehicles = {}

    def rent_vehicle(self, vehicle_id, vehicle_name):
        if vehicle_id in self.available_vehicles:
            del self.available_vehicles[vehicle_id]
            print(f"Vehicle {vehicle_name} with ID {vehicle_id} rented successfully.")
        else:
            print(f"Vehicle with ID {vehicle_id} is not available for rent.")

    def return_vehicle(self, vehicle_id, vehicle_name):
        if vehicle_id not in self.available_vehicles:
            self.available_vehicles[vehicle_id] = vehicle_name
            print(f"Vehicle {vehicle_name} with ID {vehicle_id} returned successfully.")
        else:
            print(f"Vehicle with ID {vehicle_id} is already available.")

    def display_available_vehicles(self):
        if self.available_vehicles:
            print("Available Vehicles:")
            for vehicle_id, vehicle_name in self.available_vehicles.items():
                print(f"ID: {vehicle_id}, Name: {vehicle_name}")
        else:
            print("No vehicles available for rent.")


# Test the VehicleRentalSystem class
vehicle_rental_system = VehicleRentalSystem()

# Add some vehicles to the system
vehicle_rental_system.available_vehicles = {101: "Car", 102: "Motorcycle", 103: "Van"}

# Display available vehicles
vehicle_rental_system.display_available_vehicles()
print()

# Rent a vehicle
vehicle_rental_system.rent_vehicle(102, "Motorcycle")

# Display available vehicles after renting
vehicle_rental_system.display_available_vehicles()
print()

# Return the rented vehicle
vehicle_rental_system.return_vehicle(102, "Motorcycle")

# Display available vehicles after returning
vehicle_rental_system.display_available_vehicles()
# Out:
# Available Vehicles:
# ID: 101, Name: Car
# ID: 102, Name: Motorcycle
# ID: 103, Name: Van
#
# Vehicle Motorcycle with ID 102 rented successfully.
# Available Vehicles:
# ID: 101, Name: Car
# ID: 103, Name: Van
#
# Vehicle Motorcycle with ID 102 returned successfully.
# Available Vehicles:
# ID: 101, Name: Car
# ID: 103, Name: Van
# ID: 102, Name: Motorcycle

# %%
#Problem 4: Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books, and display available books.
class Book:
    def __init__(self, book_id, title, author):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.available = True

    def __str__(self):
        return f"ID: {self.book_id}, Title: {self.title}, Author: {self.author}, Available: {self.available}"


class Library:
    def __init__(self):
        self.books = {}

    def add_book(self, book):
        self.books[book.book_id] = book

    def borrow_book(self, book_id):
        if book_id in self.books:
            if self.books[book_id].available:
                self.books[book_id].available = False
                print(f"Book '{self.books[book_id].title}' borrowed successfully.")
            else:
                print(f"Book '{self.books[book_id].title}' is already borrowed.")
        else:
            print("Book with given ID is not available in the library.")

    def display_available_books(self):
        available_books = [book for book in self.books.values() if book.available]
        if available_books:
            print("Available Books:")
            for book in available_books:
                print(book)
        else:
            print("No books available in the library.")


# Test the Library class
library = Library()

# Add some books to the library
book1 = Book(101, "Harry Potter", "J.K. Rowling")
book2 = Book(102, "The Lord of the Rings", "J.R.R. Tolkien")
book3 = Book(103, "To Kill a Mockingbird", "Harper Lee")

library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Display available books
library.display_available_books()
print()

# Borrow a book
library.borrow_book(102)

# Display available books after borrowing
library.display_available_books()
print()

# Borrow the same book again
library.borrow_book(102)
# Out:
# Available Books:
# ID: 101, Title: Harry Potter, Author: J.K. Rowling, Available: True
# ID: 102, Title: The Lord of the Rings, Author: J.R.R. Tolkien, Available: True
# ID: 103, Title: To Kill a Mockingbird, Author: Harper Lee, Available: True
#
# Book 'The Lord of the Rings' borrowed successfully.
# Available Books:
# ID: 101, Title: Harry Potter, Author: J.K. Rowling, Available: True
# ID: 103, Title: To Kill a Mockingbird, Author: Harper Lee, Available: True
#
# Book 'The Lord of the Rings' is already borrowed.

# %%
# Problem 5: Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the inventory, update product quantity, and display available products
class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

    def __str__(self):
        return f"ID: {self.product_id}, Name: {self.name}, Price: {self.price}, Quantity: {self.quantity}"


class InventorySystem:
    def __init__(self):
        self.inventory = {}

    def add_product(self, product):
        self.inventory[product.product_id] = product

    def update_quantity(self, product_id, quantity):
        if product_id in self.inventory:
            self.inventory[product_id].quantity = quantity
            print(f"Quantity for product '{self.inventory[product_id].name}' updated successfully.")
        else:
            print("Product with given ID is not available in the inventory.")

    def display_available_products(self):
        if self.inventory:
            print("Available Products:")
            for product in self.inventory.values():
                print(product)
        else:
            print("No products available in the inventory.")


# Test the InventorySystem class
inventory_system = InventorySystem()

# Add some products to the inventory
product1 = Product(101, "Laptop", 1000, 5)
product2 = Product(102, "Smartphone", 500, 10)
product3 = Product(103, "Tablet", 300, 8)

inventory_system.add_product(product1)
inventory_system.add_product(product2)
inventory_system.add_product(product3)

# Display available products
inventory_system.display_available_products()
print()

# Update quantity of a product
inventory_system.update_quantity(102, 7)

# Display available products after updating quantity
inventory_system.display_available_products()
# Out:
# Available Products:
# ID: 101, Name: Laptop, Price: 1000, Quantity: 5
# ID: 102, Name: Smartphone, Price: 500, Quantity: 10
# ID: 103, Name: Tablet, Price: 300, Quantity: 8
#
# Quantity for product 'Smartphone' updated successfully.
# Available Products:
# ID: 101, Name: Laptop, Price: 1000, Quantity: 5
# ID: 102, Name: Smartphone, Price: 500, Quantity: 7
# ID: 103, Name: Tablet, Price: 300, Quantity: 8

# %%
# Problem 6: Shape Calculation Create a class representing a shape with attributes like length, width, and height. Implement methods to calculate the area and perimeter of the shape.
class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


class Triangle(Shape):
    def calculate_area(self):
        return 0.5 * self.width * self.height

    def calculate_perimeter(self):
        return self.width + self.height + self.hypotenuse

    @property
    def hypotenuse(self):
        return (self.width ** 2 + self.height ** 2) ** 0.5


# Test the Rectangle and Triangle classes
rectangle = Rectangle(4, 5)
print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())

triangle = Triangle(width=3, height=4)
print("Triangle Area:", triangle.calculate_area())
print("Triangle Perimeter:", triangle.calculate_perimeter())
# Out:
# Rectangle Area: 20
# Rectangle Perimeter: 18
# Triangle Area: 6.0
# Triangle Perimeter: 12.0

# %%
# Problem 7: Student Management Create a class representing a student with attributes like student ID, name, and grades. Implement methods to calculate the average grade and display student details.
class Student:
    def __init__(self, student_id, name, grades=[]):
        self.student_id = student_id
        self.name = name
        self.grades = grades

    def add_grade(self, grade):
        self.grades.append(grade)

    def calculate_average_grade(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)
        else:
            return 0

    def display_details(self):
        print("Student ID:", self.student_id)
        print("Name:", self.name)
        print("Grades:", self.grades)
        print("Average Grade:", self.calculate_average_grade())


# Test the Student class
student1 = Student(1, "John Doe", [85, 90, 92])
student1.display_details()
print()

student2 = Student(2, "Alice Smith")
student2.add_grade(88)
student2.add_grade(91)
student2.display_details()
# Out:
# Student ID: 1
# Name: John Doe
# Grades: [85, 90, 92]
# Average Grade: 89.0
#
# Student ID: 2
# Name: Alice Smith
# Grades: [88, 91]
# Average Grade: 89.5

# %%
# Problem 8: Email Management Create a class representing an email with attributes like sender, recipient, and subject. Implement methods to send an email and display email details.
class Email:
    def __init__(self, sender, recipient, subject, message):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.message = message

    def send_email(self):
        print("Email sent successfully.")
        print("Sender:", self.sender)
        print("Recipient:", self.recipient)
        print("Subject:", self.subject)
        print("Message:", self.message)

    def display_email_details(self):
        print("Email Details:")
        print("Sender:", self.sender)
        print("Recipient:", self.recipient)
        print("Subject:", self.subject)
        print("Message:", self.message)


# Test the Email class
email = Email("sender@example.com", "recipient@example.com", "Hello", "This is a test email.")
email.send_email()
print()

email.display_email_details()
# Out:
# Email sent successfully.
# Sender: sender@example.com
# Recipient: recipient@example.com
# Subject: Hello
# Message: This is a test email.
#
# Email Details:
# Sender: sender@example.com
# Recipient: recipient@example.com
# Subject: Hello
# Message: This is a test email.

# %%
# Problem 9: Social Media Profile Create a class representing a social media profile with attributes like username and posts. Implement methods to add posts, display posts, and search for posts by keyword.
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post):
        self.posts.append(post)

    def display_posts(self):
        print(f"Posts by {self.username}:")
        for index, post in enumerate(self.posts, start=1):
            print(f"{index}. {post}")

    def search_posts_by_keyword(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        if matching_posts:
            print(f"Posts containing '{keyword}':")
            for index, post in enumerate(matching_posts, start=1):
                print(f"{index}. {post}")
        else:
            print(f"No posts containing '{keyword}' found.")


# Test the SocialMediaProfile class
profile = SocialMediaProfile("JohnDoe")

profile.add_post("Hello, this is my first post!")
profile.add_post("Feeling excited about the new project.")
profile.add_post("Just finished reading a great book.")

profile.display_posts()
print()

profile.search_posts_by_keyword("excited")
print()

profile.search_posts_by_keyword("book")
# Out:
# Posts by JohnDoe:
# 1. Hello, this is my first post!
# 2. Feeling excited about the new project.
# 3. Just finished reading a great book.
#
# Posts containing 'excited':
# 1. Feeling excited about the new project.
#
# Posts containing 'book':
# 1. Just finished reading a great book.

# %%
# Problem 10: ToDo List Create a class representing a ToDo list with attributes like tasks and due dates. Implement methods to add tasks, mark tasks as completed, and display pending tasks.
class ToDoList:
    def __init__(self):
        self.tasks = {}

    def add_task(self, task, due_date=None):
        self.tasks[task] = due_date

    def mark_task_as_completed(self, task):
        if task in self.tasks:
            del self.tasks[task]
            print(f"Task '{task}' marked as completed.")
        else:
            print("Task not found in the ToDo list.")

    def display_pending_tasks(self):
        pending_tasks = [task for task, due_date in self.tasks.items() if due_date is None]
        if pending_tasks:
            print("Pending Tasks:")
            for index, task in enumerate(pending_tasks, start=1):
                print(f"{index}. {task}")
        else:
            print("No pending tasks in the ToDo list.")


# Test the ToDoList class
todo_list = ToDoList()

todo_list.add_task("Complete assignment", "2024-02-15")
todo_list.add_task("Buy groceries")
todo_list.add_task("Call John", "2024-02-20")

todo_list.display_pending_tasks()
print()

todo_list.mark_task_as_completed("Buy groceries")

todo_list.display_pending_tasks()
# Out:
# Pending Tasks:
# 1. Buy groceries
#
# Task 'Buy groceries' marked as completed.
# No pending tasks in the ToDo list.
